# %%
import pandas as pd
import boto3
import os
from urllib.parse import urlparse
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading

query_for_data = """
WITH ranked_replacements AS (
    SELECT
        dvss1.DEAL_VOUCHER_SUB_CATEGORY_ID,
        dvsc.name AS sub_category_name,
        dvc.name AS category_name,

        dvss1.SITE_ID AS missing_image_site_id,
        sm.site_name AS missing_site_name,
        dvss1.IMAGE_URL AS missing_image_url,

        dvss2.SITE_ID AS available_image_site_id,
        sa.site_name AS available_site_name,
        dvss2.IMAGE_URL AS available_image_url,

        ROW_NUMBER() OVER (
            PARTITION BY dvss1.DEAL_VOUCHER_SUB_CATEGORY_ID, dvss1.SITE_ID
            ORDER BY ABS(dvss1.SITE_ID - dvss2.SITE_ID)
        ) AS rn
    FROM
        DEAL_VOUCHER_SUB_CATEGORY_SITE dvss1
    LEFT JOIN
        DEAL_VOUCHER_SUB_CATEGORY_SITE dvss2
        ON dvss1.DEAL_VOUCHER_SUB_CATEGORY_ID = dvss2.DEAL_VOUCHER_SUB_CATEGORY_ID
        AND dvss1.SITE_ID <> dvss2.SITE_ID
        AND dvss2.IMAGE_URL IS NOT NULL
    JOIN deal_voucher_sub_category dvsc ON dvsc.id = dvss1.DEAL_VOUCHER_SUB_CATEGORY_ID
    JOIN deal_voucher_category dvc ON dvc.id = dvsc.parent_id
    LEFT JOIN site sm ON sm.id = dvss1.SITE_ID
    LEFT JOIN site sa ON sa.id = dvss2.SITE_ID

    WHERE
        dvss1.IMAGE_URL IS NULL
    and dvss1.DEAL_VOUCHER_SUB_CATEGORY_ID = 231
),
SELECT
    DEAL_VOUCHER_SUB_CATEGORY_ID,
    sub_category_name,
    category_name,
    missing_image_site_id,
    missing_site_name,
    missing_image_url,
    available_image_site_id,
    available_site_name,
    available_image_url
FROM
    ranked_replacements
WHERE
    rn = 1
order by sub_category_name;
"""

# Read the CSV
df = pd.read_csv('Result_14.csv')

df['AVAILABLE_IMAGE_SITE_ID'] = df['AVAILABLE_IMAGE_SITE_ID'].astype('Int64')
# Filter rows with missing images but available images
missing_with_available = df[
    (df['MISSING_IMAGE_SITE_ID'].notna()) & 
    (df['AVAILABLE_IMAGE_SITE_ID'].notna()) & 
    (df['AVAILABLE_IMAGE_URL'].notna()) &
    (df['AVAILABLE_IMAGE_URL'] != '')
]

print(f"Found {len(missing_with_available)} rows with missing images that have available images")
# Thread-safe counter and log
success_count = 0
pairings_log = []
lock = threading.Lock()

def copy_single_image(row):
    global success_count, pairings_log
    
    sub_category_id = row['DEAL_VOUCHER_SUB_CATEGORY_ID']
    missing_site_id = row['MISSING_IMAGE_SITE_ID']
    available_url = row['AVAILABLE_IMAGE_URL']
    
    # Generate the new URL for the missing site
    new_url = f"https://static.wowcher.co.uk/images/seo/subcategory/{sub_category_id}-{missing_site_id}.jpg"
    
    # Extract S3 key from the new URL
    parsed_url = urlparse(new_url)
    s3_key = parsed_url.path.lstrip('/')
    
    try:
        # Initialize S3 client for this thread
        s3_client = boto3.client('s3')
        
        # Copy image directly using S3 copy
        copy_source = {
            'Bucket': 'static.wowcher.co.uk',
            'Key': urlparse(available_url).path.lstrip('/')
        }
        
        s3_client.copy(
            copy_source, 
            'static.wowcher.co.uk', 
            s3_key,
            ExtraArgs={
                'CacheControl': 'no-cache',
                'ContentType': 'image/jpeg'
            }
        )
        
        with lock:
            pairings_log.append({
                'sub_category_id': sub_category_id,
                'site_id': missing_site_id,
                'source_url': available_url,
                'destination_url': new_url,
                'status': 'success'
            })
            success_count += 1
        
        return True
    except Exception as e:
        with lock:
            pairings_log.append({
                'sub_category_id': sub_category_id,
                'site_id': missing_site_id,
                'source_url': available_url,
                'destination_url': new_url,
                'status': f'failed: {str(e)}'
            })
            print(f"Failed to copy image for sub_category_id={sub_category_id}, site_id={missing_site_id}: {e}")
        
        return False

# Process with 100 workers
with ThreadPoolExecutor(max_workers=100) as executor:
    # Submit all tasks
    future_to_row = {executor.submit(copy_single_image, row): row for _, row in missing_with_available.iterrows()}
    
    # Wait for completion
    for future in as_completed(future_to_row):
        try:
            future.result()
        except Exception as e:
            print(f"Worker thread failed: {e}")

# Save pairings log to CSV
pairings_df = pd.DataFrame(pairings_log)
log_filename = f'image_copy_pairings_{datetime.now().strftime("%Y%m%d_%H%M%S")}.csv'
pairings_df.to_csv(log_filename, index=False)

print(f"Summary: {success_count}/{len(missing_with_available)} images successfully copied")
print(f"Pairings log saved to {log_filename}")
# Out:
# Found 0 rows with missing images that have available images
# Summary: 0/0 images successfully copied
# Pairings log saved to image_copy_pairings_20250804_115656.csv

# %%
import pandas as pd
import os
from datetime import datetime
df = pd.read_csv('image_copy_pairings_20250729_113645.csv')

def generate_sql_updates(pairings_df, output_file=None):
    """
    Generate SQL UPDATE statements for the image pairings.
    
    Args:
        pairings_df: DataFrame with columns ['sub_category_id', 'site_id', 'destination_url', 'status']
        output_file: Optional file path to save SQL statements
    """
    
    # Filter only successful uploads
    successful_uploads = pairings_df[pairings_df['status'] == 'success'].copy()
    
    if successful_uploads.empty:
        print("No successful uploads found to generate SQL for.")
        return
    
    # Group by sub_category_id to create IN clauses
    sql_statements = []
    
    for sub_category_id, group in successful_uploads.groupby('sub_category_id'):
        site_ids = group['site_id'].tolist()
        
        # Create the SQL statement with dynamic URL construction
        site_ids_str = ','.join(map(str, site_ids))
        sql = f"""UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE 
SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/{sub_category_id}-'|| SITE_ID||'.jpg' 
WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = {sub_category_id} 
AND SITE_ID IN ({site_ids_str});"""
        
        sql_statements.append(sql)
    
    # Print all SQL statements
    print(f"Generated {len(sql_statements)} SQL UPDATE statements:")
    print("=" * 80)
    
    for i, sql in enumerate(sql_statements, 1):
        print(f"-- Statement {i}")
        print(sql)
        print()
    
    # Save to file if specified
    if output_file:
        with open(output_file, 'w') as f:
            f.write(f"-- SQL UPDATE statements generated on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            f.write(f"-- Total statements: {len(sql_statements)}\n")
            f.write("=" * 80 + "\n\n")
            
            for i, sql in enumerate(sql_statements, 1):
                f.write(f"-- Statement {i}\n")
                f.write(sql + "\n\n")
        
        print(f"SQL statements saved to: {output_file}")
    
    return sql_statements

# Generate SQL for the copied images process
# Use the pairings_df from your current run
if 'df' in locals():
    generate_sql_updates(df, 'sql_updates_copied_images.sql')
else:
    print("No pairings_df found. Run the image copy process first.")
# Out:
# Generated 174 SQL UPDATE statements:
# ================================================================================
# -- Statement 1
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/6-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 6
# AND SITE_ID IN (275849);
#
# -- Statement 2
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/8-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 8
# AND SITE_ID IN (275849);
#
# -- Statement 3
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/12-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 12
# AND SITE_ID IN (275849);
#
# -- Statement 4
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/15-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 15
# AND SITE_ID IN (275849);
#
# -- Statement 5
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/19-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 19
# AND SITE_ID IN (275849);
#
# -- Statement 6
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/22-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 22
# AND SITE_ID IN (275849);
#
# -- Statement 7
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/23-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 23
# AND SITE_ID IN (275869,275874,275871,275872,275865,275873,275875,275870,275868,275860,275876,275866,275867,275861,275880,275878,276148,275893,275879,275892,275864,275885,275889,276146,275883,275888,276147,276158,276149,275884,275890,275774,275775,275784,275776,275791,275797,275782,275789,275786,275851,275783,275852,275855,275787,275790,275850,275785,275856,275858,275863,275857,275859);
#
# -- Statement 8
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/26-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 26
# AND SITE_ID IN (276557,276558,276563,276562,276565,276560,276559,276561,276564,276566,276567,276568,276571,276570,276573,276569,276572,276575,276574,276578,276545,276576,276591,276599,276602,276547,276587,276598,276554,276555,276589,276603,276596,276546,276583,276577,276594,276590,276548,276586,276543,276551,276595,276592,276550,276553,276556,276584,276588,276593,276597,276552,276585);
#
# -- Statement 9
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/31-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 31
# AND SITE_ID IN (275791,275776,275790,275786,275857,275784,275782,275851,275888,275880,275783,275855,275859,275797,275868,275878,275852,275787,275890,275785,275775,275860,275876,275870,275858,275871,275865,275866,275885,275856,275861,275863,275883,275789,275867,275889,275875,275850,275892,275869,275872,275873,275874,275864,275893,276146,275879,275884,276158,276148,276147,276149,275774);
#
# -- Statement 10
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/36-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 36
# AND SITE_ID IN (275849);
#
# -- Statement 11
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/44-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 44
# AND SITE_ID IN (275849);
#
# -- Statement 12
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/47-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 47
# AND SITE_ID IN (275849);
#
# -- Statement 13
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/49-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 49
# AND SITE_ID IN (275849);
#
# -- Statement 14
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/52-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 52
# AND SITE_ID IN (276577,276562,276599,276548,276559,276568,276558,276551,276593,276583,276596,276557,276574,276590,276589,276563,276552,276565,276571,276594,276576,276575,276546,276561,276556,276597,276585,276602,276586,276569,276560,276554,276543,276555,276584,276588,276564,276566,276595,276567,276570,276553,276578,276603,276573,276550,276587,276572,276592,276547,276591,276545,276598);
#
# -- Statement 15
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/63-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 63
# AND SITE_ID IN (276262);
#
# -- Statement 16
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/65-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 65
# AND SITE_ID IN (276578,276592,276574,276598,276589,277151,276586,276593,276588,277154,276577,276576,276575,276597,276594,276590,276573,277189,276599,276595,277155,276587,276583,276584,276543,276603,276585,276602,276570,276591,276569,277157,276571,277156,276596,276572,276545,276552,276548,276550,276551,276546,276553,276559,276561,276555,276547,276562,276556,276560,276558,276557,276554,276568,276566,276567,276564,276565,276563);
#
# -- Statement 17
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/69-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 69
# AND SITE_ID IN (275782,275774,275784,275783,275776,275785,275861,275789,275786,275787,275790,275866,275865,275864,275863,275871,275869,275880,275867,275872,275884,275874,275868,275883,275876,275873,275870,275875,275879,275885,276146,275855,275791,275889,276149,275888,275878,275850,275851,275893,275860,275892,275858,276148,275859,276147,275857,276158,275852,275797,275890,275856,275775);
#
# -- Statement 18
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/70-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 70
# AND SITE_ID IN (275849);
#
# -- Statement 19
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/72-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 72
# AND SITE_ID IN (275861);
#
# -- Statement 20
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/76-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 76
# AND SITE_ID IN (275849);
#
# -- Statement 21
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/82-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 82
# AND SITE_ID IN (276565,276545,276586,276568,276583,276566,276593,276595,276594,276570,276569,276590,276576,276543,276597,276584,276558,276567,276592,276599,276598,276557,276564,276589,276559,276575,276555,276563,276603,276596,276591,276573,276556,276561,276588,276585,276602,276587,276571,276578,276560,276572,276577,276562,276574,276552,276553,276546,276548,276551,276554,276550,276547);
#
# -- Statement 22
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/83-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 83
# AND SITE_ID IN (276548,276577,276576,276554,276578,276546,276574,276603,276545,276584,276550,276557,276572,276585,276558,276588,276587,276551,276560,276561,276583,276602,276571,276586,276555,276590,276589,276599,276566,276562,276595,276591,276559,276567,276565,276569,276547,276556,276568,276598,276593,276564,276552,276563,276594,276596,276597,276553,276575,276573,276543,276592,276570);
#
# -- Statement 23
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/98-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 98
# AND SITE_ID IN (276561,276550,276553,276552,276554,276548,276576,276567,276551,276547,276577,276585,276557,276564,276572,276594,276583,276560,276565,276562,276556,276586,276595,276593,276569,276588,276603,276568,276591,276559,276597,276546,276571,276563,276570,276574,276545,276584,276598,276555,276578,276596,276575,276566,276590,276589,276602,276599,276543,276573,276592,276587,276558);
#
# -- Statement 24
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/101-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 101
# AND SITE_ID IN (275849);
#
# -- Statement 25
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/103-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 103
# AND SITE_ID IN (275849);
#
# -- Statement 26
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/104-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 104
# AND SITE_ID IN (275849);
#
# -- Statement 27
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/106-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 106
# AND SITE_ID IN (275849);
#
# -- Statement 28
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/119-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 119
# AND SITE_ID IN (275849);
#
# -- Statement 29
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/126-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 126
# AND SITE_ID IN (275849);
#
# -- Statement 30
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/129-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 129
# AND SITE_ID IN (275852,275865,275861,275850,275859);
#
# -- Statement 31
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/133-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 133
# AND SITE_ID IN (275849);
#
# -- Statement 32
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/134-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 134
# AND SITE_ID IN (275849);
#
# -- Statement 33
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/135-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 135
# AND SITE_ID IN (275849);
#
# -- Statement 34
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/185-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 185
# AND SITE_ID IN (276588,276597,276567,276586,276585,276555,276584,276572,276566,276546,276590,276573,276576,276561,276595,276575,276543,276563,276591,276578,276553,276599,276602,276603,276587,276596,276565,276592,276550,276349,276545,276589,276554,276577,276583,276598,276547,276559,276551,276564,276560,276594,276552,276562,276593,276556,276557,276548,276558,276568,276574,276569,276570,276571);
#
# -- Statement 35
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/190-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 190
# AND SITE_ID IN (276602,276552,276545,276563,276560,276551,276564,276557,276547,276554,276550,276559,276548,276603,276546,276561,276543,276556,276562,276565,276558,276555,276553,276577,276569,276568,276574,276572,276571,276567,276576,276575,276570,276573,276566,276583,276578,276585,276588,276584,276587,276586,276590,276589,276591,276593,276595,276592,276594,276596,276597,276598,276599);
#
# -- Statement 36
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/198-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 198
# AND SITE_ID IN (276543);
#
# -- Statement 37
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/203-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 203
# AND SITE_ID IN (276567,276570,276569,276568,276571,276576,276578,276573,276572,276586,276545,276587,276599,276589,276574,276575,276584,276577,276543,276593,276590,276592,276588,276559,276553,276591,276595,276558,276598,276556,276555,276597,276565,276547,276596,276548,276603,276583,276546,276594,276602,276563,276551,276560,276585,276552,276557,276550,276561,276554,276566,276562,276564);
#
# -- Statement 38
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/204-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 204
# AND SITE_ID IN (276548,276578,276585,276584,276577,276583,276587,276576,276586,276588,276589,276591,276590,276592,276543,276593,276594,276595,276598,276603,276560,276597,276568,276602,276557,276551,276552,276553,276596,276555,276569,276546,276545,276599,276575,276550,276547,276573,276564,276567,276574,276565,276572,276554,276556,276563,276566,276559,276558,276570,276561,276571,276562);
#
# -- Statement 39
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/205-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 205
# AND SITE_ID IN (276552,276548,276593,276578,276543,276565,276587,276583,276556,276546,276584,276547,276594,276562,276559,276575,276567,276551,276550,276560,276586,276563,276572,276557,276576,276568,276603,276590,276555,276553,276591,276564,276592,276571,276595,276577,276585,276545,276570,276573,276554,276596,276574,276561,276599,276566,276569,276558,276589,276597,276588,276602,276598);
#
# -- Statement 40
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/218-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 218
# AND SITE_ID IN (276595,276594,276591,276583,276602,276543,276574,276592,276558,276596,276552,276551,276569,276570,276547,276564,276548,276598,276561,276553,276589,276597,276588,276590,276563,276572,276554,276562,276566,276560,276586,276568,276550,276573,276603,276555,276546,276599,276575,276571,276578,276559,276565,276567,276556,276585,276577,276557,276587,276545,276593,276576,276584);
#
# -- Statement 41
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/222-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 222
# AND SITE_ID IN (276568,276594,276565,276578,276567,276574,276593,276573,276602,276571,276552,276566,276543,276599,276548,276585,276550,276588,276551,276586,276584,276595,276590,276587,276569,276597,276561,276557,276547,276554,276553,276603,276583,276576,276572,276570,276596,276591,276598,276560,276575,276564,276577,276592,276563,276562,276558,276589,276556,276559,276555,276546,276545);
#
# -- Statement 42
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/224-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 224
# AND SITE_ID IN (276548,276547,276563,276561,276554,276590,276552,276565,276576,276575,276560,276559,276557,276564,276570,276569,276558,276568,276546,276567,276571,276555,276556,276566,276553,276550,276577,276562,276572,276574,276578,276603,276599,276588,276585,276551,276594,276545,276593,276589,276597,276583,276598,276584,276592,276595,276596,276586,276602,276591,276543,276573,276587);
#
# -- Statement 43
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/229-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 229
# AND SITE_ID IN (275849);
#
# -- Statement 44
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/231-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 231
# AND SITE_ID IN (275868,275866,275789,276158,275784,275876,275786,275785,275850,275871,276149,275865,275859,275867,275890,275880,275851,275855,275858,275889,275885,275782,275852,275869,275863,275787,275873,275878,275856,275893,275870,275775,275797,276147,275888,275875,275883,275860,276146,275861,275791,275776,275790,275884,275774,275872,276148,275783,275857,275892,275874,275879,275864);
#
# -- Statement 45
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/235-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 235
# AND SITE_ID IN (276546,276547,276566,276558,276565,276555,276588,276569,276550,276551,276597,276571,276552,276561,276545,276568,276559,276554,276591,276570,276603,276567,276572,276576,276595,276553,276560,276556,276562,276577,276599,276589,276586,276596,276543,276593,276583,276592,276585,276575,276563,276584,276602,276590,276594,276598,276573,276564,276548,276578,276587,276557,276574);
#
# -- Statement 46
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/236-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 236
# AND SITE_ID IN (276592,276596,276573,276568,276561,276577,276548,276591,277151,276570,276590,276547,276589,276586,276558,276595,276597,276563,276567,276555,276588,277156,276599,276598,277154,276574,277189,276556,276572,276546,276602,276566,276554,277155,276565,276562,276593,276559,276551,276585,276557,276594,276564,276569,276571,277157,276560,276575,276603,276578,276552,276576,276545,276550,276587,276584,276553,276543,276583);
#
# -- Statement 47
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/238-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 238
# AND SITE_ID IN (276576,276547,276575,276574,276578,276583,276584,276586,276588,276587,276596,276590,276598,276585,276593,276592,276594,276597,276591,276589,276543,276545,276577,276553,276550,276603,276548,276599,276595,276556,276557,276552,276558,276546,276554,276602,276566,276561,276560,276564,276559,276562,276555,276569,276567,276565,276573,276568,276571,276551,276563,276570,276572);
#
# -- Statement 48
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/246-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 246
# AND SITE_ID IN (275878,275884,275876,275880,275879,275883,275875,275889,275888,276146,275885,276148,275892,275890,275893,275774,276147,276149,276158,275775,275782,275783,275776,275791,275867,275860,275851,275786,275873,275855,275790,275787,275859,275850,275870,275863,275864,275857,275789,275858,275865,275856,275869,275868,275852,275874,275866,275785,275861,275872,275797,275784,275871);
#
# -- Statement 49
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/259-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 259
# AND SITE_ID IN (275849);
#
# -- Statement 50
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/261-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 261
# AND SITE_ID IN (275849);
#
# -- Statement 51
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/383-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 383
# AND SITE_ID IN (275849);
#
# -- Statement 52
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/384-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 384
# AND SITE_ID IN (276570);
#
# -- Statement 53
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/385-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 385
# AND SITE_ID IN (275849);
#
# -- Statement 54
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/386-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 386
# AND SITE_ID IN (275849);
#
# -- Statement 55
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/387-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 387
# AND SITE_ID IN (276592,276594,276591,276597,276596,276595,276598,276545,276599,276603,276543,276602,276546,276547,276550,276552,276555,276554,276558,276567,276563,276560,276570,276559,276590,276548,276569,276571,276577,276556,276551,276568,276589,276566,276553,276565,276587,276575,276574,276585,276573,276586,276583,276561,276578,276562,276593,276584,276557,276588,276564,276572,276576);
#
# -- Statement 56
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/390-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 390
# AND SITE_ID IN (276603,276569,276556,276570,276572,276561,276566,276564,276560,276575,276584,276586,276588,276558,276563,276574,276550,276585,276543,276546,276551,276557,276554,276577,276590,276548,276555,276552,276545,276565,276567,276578,276571,276573,276562,276547,276553,276559,276589,276587,276568,276591,276583,276576,276592,276595,276598,276593,276596,276597,276594,276599,276602);
#
# -- Statement 57
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/395-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 395
# AND SITE_ID IN (276578,276564,276547,276594,276570,276596,276548,276591,276599,276565,276602,276590,276589,276568,276583,276577,276562,276551,276563,276592,276553,276545,276552,276558,276567,276546,276543,276586,276593,276595,276603,276561,276584,276575,276554,276585,276573,276569,276571,276560,276572,276556,276598,276597,276550,276555,276574,276587,276566,276588,276557,276559,276576);
#
# -- Statement 58
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/410-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 410
# AND SITE_ID IN (276669,276582);
#
# -- Statement 59
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/413-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 413
# AND SITE_ID IN (275849);
#
# -- Statement 60
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/414-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 414
# AND SITE_ID IN (275849);
#
# -- Statement 61
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/415-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 415
# AND SITE_ID IN (275849);
#
# -- Statement 62
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/416-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 416
# AND SITE_ID IN (275849);
#
# -- Statement 63
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/418-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 418
# AND SITE_ID IN (275849);
#
# -- Statement 64
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/419-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 419
# AND SITE_ID IN (275849);
#
# -- Statement 65
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/420-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 420
# AND SITE_ID IN (275849);
#
# -- Statement 66
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/425-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 425
# AND SITE_ID IN (275849);
#
# -- Statement 67
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/440-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 440
# AND SITE_ID IN (276556,276598,276558,276560,276559,276561,276565,276562,276564,276563,276570,276571,276568,276576,276572,276602,276583,276569,276567,276566,276578,276584,276574,276551,276589,276586,276603,276597,276553,276555,276591,276552,276592,276547,276587,276545,276573,276588,276590,276594,276577,276548,276585,276546,276595,276599,276596,276554,276550,276575,276593,276557,276543);
#
# -- Statement 68
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/441-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 441
# AND SITE_ID IN (276588,276559,276587,276589,276595,276591,276558,276594,276593,276576,276566,276561,276577,276565,276578,276563,276599,276545,276573,276562,276571,276555,276584,276548,276583,276547,276590,276551,276550,276560,276556,276543,276554,276567,276586,276597,276553,276546,276564,276557,276598,276592,276575,276568,276572,276585,276552,276574,276569,276570,276596,276602,276603);
#
# -- Statement 69
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/448-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 448
# AND SITE_ID IN (275849);
#
# -- Statement 70
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/452-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 452
# AND SITE_ID IN (275849);
#
# -- Statement 71
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/454-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 454
# AND SITE_ID IN (275849);
#
# -- Statement 72
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/560-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 560
# AND SITE_ID IN (275883,275786,275857,275868,275790,275776,275775,275878,275892,275867,275880,275855,275876,275890,275774,276146,275873,275858,275893,275783,276149,275889,275852,275866,275791,276158,275864,275865,275875,276147,275784,275869,275850,275872,276148,275859,275885,275782,275856,275888,275879,275863,275787,275861,275851,275797,275860,275789,275884,275785,275871,275870,275874);
#
# -- Statement 73
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/561-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 561
# AND SITE_ID IN (275859,275852,275873,275864,275874,275892,275870,275858,275875,275880,275871,275774,275878,275868,275855,275885,275883,275866,275876,275863,275861,275869,275865,275872,275857,275890,275867,275775,276148,275884,275889,275879,276149,276147,275893,275888,275860,276146,275776,275782,275787,275784,275783,275785,275786,275790,275789,275797,275791,275856,275851,275850);
#
# -- Statement 74
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/564-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 564
# AND SITE_ID IN (275789,275783,275782,275785,276148,276149,275784,275787,275775,275776,275774,275864,275790,275850,275851,275791,275797,275867,275871,275869,275786,275861,275859,275856,275860,275874,275863,275866,275873,275870,275872,275852,275865,275855,275857,275858,275868,275876,275875,275878,275880,275879,275883,275884,275889,276146,275893,275888,275892,275885,275890,276147);
#
# -- Statement 75
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/566-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 566
# AND SITE_ID IN (276148,275791,275883,275861,275784,276149,275884,275857,275867,275879,275858,275866,275870,275868,275797,275888,275873,275852,275851,275892,275876,275786,275776,275890,275774,275874,275880,276146,275863,275878,275871,275783,275789,275865,275860,275889,275893,275775,275785,275872,275885,276147,275790,275859,275787,275856,275875,275850,275855,275864,275782,275869);
#
# -- Statement 76
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/567-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 567
# AND SITE_ID IN (276588,276591,276590,276584,276585,276586,276589,276587,276593,276594,276592,276595,276578,276596,276598,276554,276599,276552,276556,276566,276555,276560,276557,276559,276603,276602,276568,276561,276551,276583,276562,276545,276553,276564,276543,276597,276550,276547,276548,276574,276572,276563,276565,276570,276558,276546,276577,276573,276575,276571,276576,276567,276569);
#
# -- Statement 77
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/568-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 568
# AND SITE_ID IN (276551,276585,276553,276547,276575,276574,276565,276571,276561,276563,276556,276578,276566,276548,276570,276546,276603,276583,276554,276588,276543,276550,276559,276573,276564,276552,276558,276560,276562,276587,276555,276557,276569,276567,276568,276586,276577,276572,276576,276584,276589,276591,276593,276595,276599,276594,276597,276592,276598,276602,276590,276596,276545);
#
# -- Statement 78
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/571-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 571
# AND SITE_ID IN (276583,276568,276553,276573,276556,276575,276599,276558,276566,276603,276551,276560,276578,276543,276598,276562,276572,276564,276592,276587,276571,276546,276559,276569,276585,276590,276577,276584,276561,276595,276567,276547,276597,276552,276550,276545,276588,276563,276574,276586,276594,276548,276555,276602,276596,276589,276554,276570,276576,276591,276557,276565,276593);
#
# -- Statement 79
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/572-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 572
# AND SITE_ID IN (276585);
#
# -- Statement 80
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/574-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 574
# AND SITE_ID IN (276343);
#
# -- Statement 81
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/575-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 575
# AND SITE_ID IN (276158,275774,275785,275776,275786,275784,275782,275783,275787,275852,275850,275851,275791,275860,275789,275797,275790,276147,275775,275873,275859,275885,275868,275892,275858,275857,275856,275855,276149,275876,275875,275890,276148,275864,275871,275878,276146,275863,275889,275866,275865,275883,275861,275874,275884,275867,275879,275872,275880,275893,275869,275888,275870);
#
# -- Statement 82
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/576-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 576
# AND SITE_ID IN (275776,275782,275775,275789,275786,275784,275783,275785,275787,275790,275791,275858,275864,275855,275867,275797,275868,275859,275861,275869,275850,275851,275856,275857,275852,275865,275872,275883,276148,275873,275860,275863,275874,275885,275880,275890,275888,275866,275889,276149,275875,275876,276146,276158,275871,275879,276147,275870,275878,275774,275884,275893,276575,275892);
#
# -- Statement 83
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/580-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 580
# AND SITE_ID IN (275860,275857,275859,275851,275867,275864,276148,275889,275774,275888,275791,275893,275789,275786,275782,275890,275775,275871,275783,275869,275797,275785,275856,275866,275863,275790,275776,276146,275787,275858,275861,275855,276147,275868,275892,275870,275784,276158,275850,275872,275865,276149,275852,275885,275875,275883,275884,275873,275876,275879,275874,275880,275878);
#
# -- Statement 84
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/586-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 586
# AND SITE_ID IN (275849);
#
# -- Statement 85
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/587-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 587
# AND SITE_ID IN (276591,276545,276562,276586,276555,276596,276584,276574,276592,276583,276551,276550,276595,276572,276598,276561,276543,276593,276548,276588,276587,276566,276577,276554,276597,276556,276565,276589,276575,276599,276578,276603,276552,276559,276564,276569,276560,276568,276585,276602,276546,276571,276567,276576,276558,276570,276594,276553,276547,276590,276557,276573,276563);
#
# -- Statement 86
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/591-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 591
# AND SITE_ID IN (275875,275776,275892,275856,275878,275880,275782,275874,275784,275888,276146,275791,275893,275872,275785,276148,276149,275885,275867,275870,275857,275787,275790,275883,275871,275890,276147,275876,275889,275851,275783,275859,275852,275775,276158,275860,275884,275863,275868,275786,275797,275864,275858,275861,275879,275789,275774,275865,275869,275873,275866,275855,275850);
#
# -- Statement 87
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/593-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 593
# AND SITE_ID IN (276603,276543,276546,276547,276548,276557,276554,276558,276560,276550,276559,276556,276551,276552,276553,276555,276561,276563,276562,276569,276567,276570,276572,276565,276568,276564,276571,276566,276574,276575,276573,276577,276576,276583,276595,276545,276586,276597,276598,276602,276593,276596,276594,276585,276578,276590,276599,276584,276587,276591,276588,276592,276589);
#
# -- Statement 88
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/595-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 595
# AND SITE_ID IN (275867,275852);
#
# -- Statement 89
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/596-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 596
# AND SITE_ID IN (275849);
#
# -- Statement 90
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/597-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 597
# AND SITE_ID IN (275849);
#
# -- Statement 91
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/603-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 603
# AND SITE_ID IN (275850);
#
# -- Statement 92
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/606-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 606
# AND SITE_ID IN (275849);
#
# -- Statement 93
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/607-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 607
# AND SITE_ID IN (276669,275849,277151);
#
# -- Statement 94
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/608-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 608
# AND SITE_ID IN (276669);
#
# -- Statement 95
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/609-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 609
# AND SITE_ID IN (276669,277151);
#
# -- Statement 96
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/610-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 610
# AND SITE_ID IN (276669);
#
# -- Statement 97
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/611-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 611
# AND SITE_ID IN (277151,276669);
#
# -- Statement 98
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/612-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 612
# AND SITE_ID IN (276669,277151);
#
# -- Statement 99
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/613-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 613
# AND SITE_ID IN (276669);
#
# -- Statement 100
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/614-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 614
# AND SITE_ID IN (276669);
#
# -- Statement 101
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/615-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 615
# AND SITE_ID IN (276669,275849,275850,277151);
#
# -- Statement 102
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/616-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 616
# AND SITE_ID IN (276669,277151);
#
# -- Statement 103
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/617-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 617
# AND SITE_ID IN (277151);
#
# -- Statement 104
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/618-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 618
# AND SITE_ID IN (276669);
#
# -- Statement 105
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/619-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 619
# AND SITE_ID IN (276582,276669);
#
# -- Statement 106
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/620-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 620
# AND SITE_ID IN (276669);
#
# -- Statement 107
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/621-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 621
# AND SITE_ID IN (275850,276669);
#
# -- Statement 108
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/622-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 622
# AND SITE_ID IN (276669);
#
# -- Statement 109
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/623-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 623
# AND SITE_ID IN (276669);
#
# -- Statement 110
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/624-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 624
# AND SITE_ID IN (276669);
#
# -- Statement 111
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/625-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 625
# AND SITE_ID IN (276669);
#
# -- Statement 112
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/626-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 626
# AND SITE_ID IN (276669,277151);
#
# -- Statement 113
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/628-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 628
# AND SITE_ID IN (276669);
#
# -- Statement 114
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/629-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 629
# AND SITE_ID IN (276669);
#
# -- Statement 115
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/630-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 630
# AND SITE_ID IN (275850,276669);
#
# -- Statement 116
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/631-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 631
# AND SITE_ID IN (275866,276669);
#
# -- Statement 117
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/632-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 632
# AND SITE_ID IN (276669,275865);
#
# -- Statement 118
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/633-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 633
# AND SITE_ID IN (275852,276669);
#
# -- Statement 119
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/634-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 634
# AND SITE_ID IN (275774,276669);
#
# -- Statement 120
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/635-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 635
# AND SITE_ID IN (276669,275860);
#
# -- Statement 121
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/636-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 636
# AND SITE_ID IN (276669);
#
# -- Statement 122
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/637-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 637
# AND SITE_ID IN (276669,275861);
#
# -- Statement 123
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/639-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 639
# AND SITE_ID IN (276669);
#
# -- Statement 124
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/640-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 640
# AND SITE_ID IN (276669);
#
# -- Statement 125
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/641-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 641
# AND SITE_ID IN (276669,275885);
#
# -- Statement 126
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/642-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 642
# AND SITE_ID IN (276669);
#
# -- Statement 127
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/643-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 643
# AND SITE_ID IN (276669);
#
# -- Statement 128
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/644-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 644
# AND SITE_ID IN (276669);
#
# -- Statement 129
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/645-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 645
# AND SITE_ID IN (276669,275867);
#
# -- Statement 130
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/646-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 646
# AND SITE_ID IN (276669,275892);
#
# -- Statement 131
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/647-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 647
# AND SITE_ID IN (275790,275852,275797,275856,275850,275860,275892,275876,275867,275787,275868,275865,275869,275782,275861,275873,275890,275871,275888,275879,275878,275875,276669,275880,275858,275889,275784,275775,275776,275866,275774,275864,275857);
#
# -- Statement 132
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/648-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 648
# AND SITE_ID IN (275782,275850,275889,275866,275861,275865,276669);
#
# -- Statement 133
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/649-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 649
# AND SITE_ID IN (275849,276669);
#
# -- Statement 134
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/650-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 650
# AND SITE_ID IN (276669);
#
# -- Statement 135
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/651-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 651
# AND SITE_ID IN (276669);
#
# -- Statement 136
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/653-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 653
# AND SITE_ID IN (275849,276669);
#
# -- Statement 137
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/654-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 654
# AND SITE_ID IN (276669);
#
# -- Statement 138
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/655-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 655
# AND SITE_ID IN (276669);
#
# -- Statement 139
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/656-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 656
# AND SITE_ID IN (275849,276669);
#
# -- Statement 140
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/657-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 657
# AND SITE_ID IN (276669);
#
# -- Statement 141
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/658-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 658
# AND SITE_ID IN (276669);
#
# -- Statement 142
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/659-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 659
# AND SITE_ID IN (276669);
#
# -- Statement 143
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/660-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 660
# AND SITE_ID IN (276669);
#
# -- Statement 144
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/661-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 661
# AND SITE_ID IN (276669);
#
# -- Statement 145
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/662-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 662
# AND SITE_ID IN (276669);
#
# -- Statement 146
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/663-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 663
# AND SITE_ID IN (276669);
#
# -- Statement 147
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/664-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 664
# AND SITE_ID IN (276669);
#
# -- Statement 148
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/665-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 665
# AND SITE_ID IN (276669);
#
# -- Statement 149
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/666-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 666
# AND SITE_ID IN (276669);
#
# -- Statement 150
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/667-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 667
# AND SITE_ID IN (276669,275850);
#
# -- Statement 151
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/668-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 668
# AND SITE_ID IN (276669);
#
# -- Statement 152
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/669-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 669
# AND SITE_ID IN (276669);
#
# -- Statement 153
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/670-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 670
# AND SITE_ID IN (276669);
#
# -- Statement 154
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/671-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 671
# AND SITE_ID IN (276669);
#
# -- Statement 155
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/672-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 672
# AND SITE_ID IN (276669);
#
# -- Statement 156
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/673-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 673
# AND SITE_ID IN (276669,276158);
#
# -- Statement 157
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/674-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 674
# AND SITE_ID IN (276669);
#
# -- Statement 158
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/675-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 675
# AND SITE_ID IN (276669);
#
# -- Statement 159
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/676-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 676
# AND SITE_ID IN (276669,276582);
#
# -- Statement 160
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/678-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 678
# AND SITE_ID IN (276582,276669,275851);
#
# -- Statement 161
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/682-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 682
# AND SITE_ID IN (276669);
#
# -- Statement 162
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/684-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 684
# AND SITE_ID IN (275775,275850,275860,275866,275849,275865,275861,275852,275868,276669);
#
# -- Statement 163
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/686-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 686
# AND SITE_ID IN (276669);
#
# -- Statement 164
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/687-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 687
# AND SITE_ID IN (276582,276669);
#
# -- Statement 165
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/688-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 688
# AND SITE_ID IN (275866,275865,275868,275860,275880,275790,275850,275852,276669,275775);
#
# -- Statement 166
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/689-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 689
# AND SITE_ID IN (276669);
#
# -- Statement 167
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/690-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 690
# AND SITE_ID IN (275864,276669,275889);
#
# -- Statement 168
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/692-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 692
# AND SITE_ID IN (276669);
#
# -- Statement 169
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/694-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 694
# AND SITE_ID IN (275880,275883,276669);
#
# -- Statement 170
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/695-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 695
# AND SITE_ID IN (276669);
#
# -- Statement 171
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/696-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 696
# AND SITE_ID IN (276669);
#
# -- Statement 172
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/697-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 697
# AND SITE_ID IN (276669);
#
# -- Statement 173
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/698-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 698
# AND SITE_ID IN (275865,275866,275852,275860,275868,276669,275880,275850,275849,275861);
#
# -- Statement 174
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/699-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 699
# AND SITE_ID IN (276669);
#
# SQL statements saved to: sql_updates_copied_images.sql

# %%
import pandas as pd
import boto3
import requests
import os
from urllib.parse import urlparse
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
from openai import OpenAI

load_dotenv()

print(os.getenv('OPEN_AI_API_KEY'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8 import threading
#       9 from openai import OpenAI
# ---> 11 load_dotenv()
#      13 print(os.getenv('OPEN_AI_API_KEY'))
#
# NameError: name 'load_dotenv' is not defined

# %%
import pandas as pd
import boto3
import requests
import os
from urllib.parse import urlparse
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading
from openai import OpenAI
import base64

# Read the CSV
df = pd.read_csv('/Users/elliottoates/Desktop/streamlit-image-review/Result_14.csv')
#df['AVAILABLE_IMAGE_SITE_ID'] = df['AVAILABLE_IMAGE_SITE_ID'].astype('Int64')

# Find subcategories with no available images at all
subcategories_with_no_images = df[
    (df['MISSING_IMAGE_SITE_ID'].notna()) & 
    (df['AVAILABLE_IMAGE_SITE_ID'].isna()) & 
    (df['AVAILABLE_IMAGE_URL'].isna() | (df['AVAILABLE_IMAGE_URL'] == ''))
]

# Get unique subcategory-category pairs that need images
unique_subcategories = subcategories_with_no_images[['DEAL_VOUCHER_SUB_CATEGORY_ID', 'SUB_CATEGORY_NAME', 'CATEGORY_NAME']].drop_duplicates()

# Filter out rows where sub_category_name contains 'DONOT'
unique_subcategories = unique_subcategories[~unique_subcategories['SUB_CATEGORY_NAME'].str.contains('DONOT', case=False, na=False)]

print(f"Found {len(unique_subcategories)} unique subcategories that need new images generated")

# Initialize OpenAI client
client = OpenAI(api_key=os.getenv('OPEN_AI_API_KEY'))

# Thread-safe counter and log
success_count = 0
pairings_log = []
lock = threading.Lock()

def generate_and_distribute_image(row):
    global success_count, pairings_log
    
    sub_category_id = row['DEAL_VOUCHER_SUB_CATEGORY_ID']
    sub_category_name = row['SUB_CATEGORY_NAME']
    category_name = row['CATEGORY_NAME']
    
    try:
        # Generate image with OpenAI
        prompt = f"can you make an image for my {sub_category_name} subcategory button on my eccommerce website. The subcategory falls under the {category_name} category. Photorealistic please. No text. Leave decent space between main subject and edge of images."
        
        response = client.images.generate(
            model="gpt-image-1",
            prompt=prompt,
            n=1,
            size="1024x1024",
            quality="medium",
        )
        
        # Decode base64 image data
        image_data = base64.b64decode(response.data[0].b64_json)
        print(f"Image generated for sub_category_id={sub_category_id}")

        # Save the generated image
        temp_file = f"generated_image_{sub_category_id}_{threading.get_ident()}.jpg"
        
        with open(temp_file, 'wb') as f:
            f.write(image_data)
        
        # Initialize S3 client for this thread
        s3_client = boto3.client('s3')
        
        # Find all missing site IDs for this subcategory
        missing_sites = subcategories_with_no_images[
            subcategories_with_no_images['DEAL_VOUCHER_SUB_CATEGORY_ID'] == sub_category_id
        ]['MISSING_IMAGE_SITE_ID'].unique()
        
        uploaded_count = 0
        for site_id in missing_sites:
            # Generate the new URL for the missing site
            new_url = f"https://static.wowcher.co.uk/images/seo/subcategory/{sub_category_id}-{site_id}.jpg"
            
            # Extract S3 key from the new URL
            parsed_url = urlparse(new_url)
            s3_key = parsed_url.path.lstrip('/')
            
            # Upload to S3 with cache control and content type
            s3_client.upload_file(
                temp_file, 
                'static.wowcher.co.uk', 
                s3_key,
                ExtraArgs={
                    'CacheControl': 'no-cache',
                    'ContentType': 'image/jpeg'
                }
            )
            
            with lock:
                pairings_log.append({
                    'sub_category_id': sub_category_id,
                    'sub_category_name': sub_category_name,
                    'category_name': category_name,
                    'site_id': site_id,
                    'source_url': 'generated_image',
                    'destination_url': new_url,
                    'status': 'success'
                })
                uploaded_count += 1
        
        if uploaded_count > 0:
            print(f"Image distributed to {uploaded_count} site(s) for sub_category_id={sub_category_id}")
        
        success_count += uploaded_count
        
        return True
        
    except Exception as e:
        with lock:
            pairings_log.append({
                'sub_category_id': sub_category_id,
                'sub_category_name': sub_category_name,
                'category_name': category_name,
                'site_id': 'N/A',
                'source_url': 'N/A',
                'destination_url': 'N/A',
                'status': f'failed: {str(e)}'
            })
            print(f"Failed to generate/upload image for sub_category_id={sub_category_id}: {e}")
        
        return False
    
    finally:
        # Clean up temp file
        if os.path.exists(temp_file):
            os.remove(temp_file)

# Process with 10 workers (fewer for API calls)
with ThreadPoolExecutor(max_workers=10) as executor:
    # Submit all tasks
    future_to_row = {executor.submit(generate_and_distribute_image, row): row for _, row in unique_subcategories.iterrows()}
    
    # Wait for completion
    for future in as_completed(future_to_row):
        try:
            future.result()
        except Exception as e:
            print(f"Worker thread failed: {e}")

# Save pairings log to CSV
pairings_df = pd.DataFrame(pairings_log)
log_filename = f'generated_image_pairings_noSub_{datetime.now().strftime("%Y%m%d_%H%M%S")}.csv'
pairings_df.to_csv(log_filename, index=False)

print(f"Summary: {success_count} images successfully uploaded")
print(f"Pairings log saved to {log_filename}")
# Out:
# Found 1 unique subcategories that need new images generated
# Image generated for sub_category_id=240
# Image distributed to 106 site(s) for sub_category_id=240
# Summary: 106 images successfully uploaded
# Pairings log saved to generated_image_pairings_noSub_20250804_120204.csv

# %%
import pandas as pd
import os
from datetime import datetime
import pandas as pd
import os
from datetime import datetime

def generate_sql_updates(pairings_df, output_file=None):
    """
    Generate SQL UPDATE statements for the image pairings.
    
    Args:
        pairings_df: DataFrame with columns ['sub_category_id', 'site_id', 'destination_url', 'status']
        output_file: Optional file path to save SQL statements
    """
    
    # Filter only successful uploads
    successful_uploads = pairings_df[pairings_df['status'] == 'success'].copy()
    
    if successful_uploads.empty:
        print("No successful uploads found to generate SQL for.")
        return
    
    # Group by sub_category_id to create IN clauses
    sql_statements = []
    
    for sub_category_id, group in successful_uploads.groupby('sub_category_id'):
        site_ids = group['site_id'].tolist()
        
        # Create the SQL statement with dynamic URL construction
        site_ids_str = ','.join(map(str, site_ids))
        sql = f"""UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE 
SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/{sub_category_id}-'|| SITE_ID||'.jpg' 
WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = {sub_category_id} 
AND SITE_ID IN ({site_ids_str});"""
        
        sql_statements.append(sql)
    
    # Print all SQL statements
    print(f"Generated {len(sql_statements)} SQL UPDATE statements:")
    print("=" * 80)
    
    for i, sql in enumerate(sql_statements, 1):
        print(f"-- Statement {i}")
        print(sql)
        print()
    
    # Save to file if specified
    if output_file:
        with open(output_file, 'w') as f:
            f.write(f"-- SQL UPDATE statements generated on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            f.write(f"-- Total statements: {len(sql_statements)}\n")
            f.write("=" * 80 + "\n\n")
            
            for i, sql in enumerate(sql_statements, 1):
                f.write(f"-- Statement {i}\n")
                f.write(sql + "\n\n")
        
        print(f"SQL statements saved to: {output_file}")
    
    return sql_statements

generate_sql_updates(pairings_df, 'sql_updates.sql')
# Out:
# Generated 1 SQL UPDATE statements:
# ================================================================================
# -- Statement 1
# UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE
# SET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/240-'|| SITE_ID||'.jpg'
# WHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 240
# AND SITE_ID IN (275774,275775,275776,275782,275783,275784,275785,275786,275787,275789,275790,275791,275797,275850,275851,275852,275855,275856,275857,275858,275859,275860,275861,275863,275864,275865,275866,275867,275868,275869,275870,275871,275872,275873,275874,275875,275876,275878,275879,275880,275883,275884,275885,275888,275889,275890,275892,275893,276146,276147,276148,276149,276158,276543,276545,276546,276547,276548,276550,276551,276552,276553,276554,276555,276556,276557,276558,276559,276560,276561,276562,276563,276564,276565,276566,276567,276568,276569,276570,276571,276572,276573,276574,276575,276576,276577,276578,276583,276584,276585,276586,276587,276588,276589,276590,276591,276592,276593,276594,276595,276596,276597,276598,276599,276602,276603);
#
# SQL statements saved to: sql_updates.sql
# ["UPDATE DEAL_VOUCHER_SUB_CATEGORY_SITE \nSET IMAGE_URL = 'https://static.wowcher.co.uk/images/seo/subcategory/240-'|| SITE_ID||'.jpg' \nWHERE DEAL_VOUCHER_SUB_CATEGORY_ID = 240 \nAND SITE_ID IN (275774,275775,275776,275782,275783,275784,275785,275786,275787,275789,275790,275791,275797,275850,275851,275852,275855,275856,275857,275858,275859,275860,275861,275863,275864,275865,275866,275867,275868,275869,275870,275871,275872,275873,275874,275875,275876,275878,275879,275880,275883,275884,275885,275888,275889,275890,275892,275893,276146,276147,276148,276149,276158,276543,276545,276546,276547,276548,276550,276551,276552,276553,276554,276555,276556,276557,276558,276559,276560,276561,276562,276563,276564,276565,276566,276567,276568,276569,276570,276571,276572,276573,276574,276575,276576,276577,276578,276583,276584,276585,276586,276587,276588,276589,276590,276591,276592,276593,276594,276595,276596,276597,276598,276599,276602,276603);"]

# %%
import pandas as pd
import os
from pathlib import Path
import sys

# Read the deals CSV using absolute paths
df = pd.read_csv('/Users/elliottoates/Desktop/streamlit-image-review/stonegate/deals.csv')
dictionary = df.to_dict(orient='records')

# Get the list of image folders using absolute paths
images_dir = Path('/Users/elliottoates/Desktop/streamlit-image-review/stonegate/Images')
image_folders = [folder.name for folder in images_dir.iterdir() if folder.is_dir()]

# Function to normalize text for matching (remove spaces, underscores, and convert to lowercase)
def normalize_text(text):
    return text.strip().lower().replace(' ', '').replace('_', '')

# Function to find matching image folder for a pub_name
def find_image_folder(pub_name, image_folders):
    """
    Find the best matching image folder for a pub_name.
    Returns the folder path if found, None otherwise.
    """
    # Normalize pub_name
    normalized_pub_name = normalize_text(pub_name)
    
    # Create a mapping of normalized folder names to actual folder paths
    folder_mapping = {}
    for folder in image_folders:
        normalized_folder = normalize_text(folder)
        folder_mapping[normalized_folder] = str(images_dir / folder)
    
    # Direct match with normalized names
    if normalized_pub_name in folder_mapping:
        return folder_mapping[normalized_pub_name]
    
    # Partial match (if pub_name contains folder name or vice versa)
    for normalized_folder, folder_path in folder_mapping.items():
        if (normalized_pub_name in normalized_folder or 
            normalized_folder in normalized_pub_name):
            return folder_path
    
    return None

# Function to get image priority score for sorting
def get_image_priority(image_path):
    """
    Get priority score for image sorting.
    Lower score = higher priority.
    """
    filename = os.path.basename(image_path).lower()
    
    # Priority 0: Ends with "main" (highest priority)
    if filename.endswith('main'):
        return 0
    
    # Priority 1: Contains "main" but doesn't end with it
    if 'main' in filename and not filename.endswith('main'):
        return 1
    
    # Priority 2: All other images (will be sorted by quality later)
    return 2

# Function to estimate image quality based on file size
def get_image_quality_score(image_path):
    """
    Estimate image quality based on file size.
    Larger files generally mean higher quality.
    """
    try:
        file_size = os.path.getsize(image_path)
        return file_size
    except:
        return 0

# Function to get image files from a folder with relative paths and proper sorting
def get_images_from_folder(folder_path):
    """
    Get all image files from a folder, sorted by priority and quality.
    Returns a list of relative image file paths.
    """
    if not folder_path or not os.path.exists(folder_path):
        return []
    
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp'}
    image_files = []
    
    try:
        for file in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file)
            if os.path.isfile(file_path):
                file_ext = os.path.splitext(file)[1].lower()
                if file_ext in image_extensions:
                    # Create relative path: Images/folder_name/filename
                    folder_name = os.path.basename(folder_path)
                    relative_path = f"Images/{folder_name}/{file}"
                    image_files.append(relative_path)
    except Exception as e:
        print(f"Error reading folder {folder_path}: {e}")
    
    # Sort images by priority and quality
    def sort_key(image_path):
        priority = get_image_priority(image_path)
        # Get the full path for quality scoring
        full_image_path = os.path.join(folder_path, os.path.basename(image_path))
        quality = get_image_quality_score(full_image_path)
        return (priority, -quality)  # Negative quality so larger files come first
    
    return sorted(image_files, key=sort_key)

# Add image folder paths and image files to each deal in the dictionary
for deal in dictionary:
    deal['image_folder_path'] = find_image_folder(deal['pub_name'], image_folders)
    deal['image_files'] = get_images_from_folder(deal['image_folder_path'])

# Get all deals without images
deals_without_images = [deal for deal in dictionary if not deal['image_files']]

# Print count of deals without images
print(f"Total deals without images: {len(deals_without_images)}")

# Print distinct pub names and count of pubs without images
distinct_pub_names_without_images = sorted(set(deal['pub_name'] for deal in deals_without_images))
print(f"Distinct pub names without images ({len(distinct_pub_names_without_images)} total):")
print("=" * 50)

# Print just the distinct pub names
for pub_name in distinct_pub_names_without_images:
    print(pub_name)

# Show example of sorted images for a deal with images
print("\n" + "=" * 50)
print("Example of sorted images for a deal with images:")
for deal in dictionary:
    if deal['image_files']:
        print(f"\nDeal: {deal['pub_name']}")
        print(f"Images ({len(deal['image_files'])} total):")
        for i, img in enumerate(deal['image_files'][:5]):  # Show first 5
            priority = get_image_priority(img)
            print(f"  Position {i}: {os.path.basename(img)} (Priority: {priority})")
        break
# Out:
# Total deals without images: 36
# Distinct pub names without images (18 total):
# ==================================================
# Gassys Cardiff
# Prince Of Teck Earls Court
# Tank & Paddle Manchester Printworks
# Temperance Fulham
# The Bay & Bracket Victoria
# The Block & Gasket Burgess Hill
# The Block & Gasket Sale
# The Boundary Reading
# The Bridge Tap London
# The Cannick Tapps London
# The Centurion Colchester
# The Cider Press Bristol
# The Distillery Leicester
# The Dockyard Portsmouth
# The Faraday Epsom
# The Garratt And Gauge Wimbledon
# The Green Dragon Croydon
# The Joiners London
#
# ==================================================
# Example of sorted images for a deal with images:

# %%
import pandas as pd
import os
from pathlib import Path
import sys

# Read the deals CSV using absolute paths
df = pd.read_csv('/Users/elliottoates/Desktop/streamlit-image-review/stonegate/deals.csv')
dictionary = df.to_dict(orient='records')

# Get the list of image folders using absolute paths
images_dir = Path('/Users/elliottoates/Desktop/streamlit-image-review/stonegate/Images')
image_folders = [folder.name for folder in images_dir.iterdir() if folder.is_dir()]

# Function to normalize text for matching (remove spaces, underscores, and convert to lowercase)
def normalize_text(text):
    return text.strip().lower().replace(' ', '').replace('_', '')

# Function to find matching image folder for a pub_name
def find_image_folder(pub_name, image_folders):
    """
    Find the best matching image folder for a pub_name.
    Returns the folder path if found, None otherwise.
    """
    # Normalize pub_name
    normalized_pub_name = normalize_text(pub_name)
    
    # Create a mapping of normalized folder names to actual folder paths
    folder_mapping = {}
    for folder in image_folders:
        normalized_folder = normalize_text(folder)
        folder_mapping[normalized_folder] = str(images_dir / folder)
    
    # Direct match with normalized names
    if normalized_pub_name in folder_mapping:
        return folder_mapping[normalized_pub_name]
    
    # Partial match (if pub_name contains folder name or vice versa)
    for normalized_folder, folder_path in folder_mapping.items():
        if (normalized_pub_name in normalized_folder or 
            normalized_folder in normalized_pub_name):
            return folder_path
    
    return None

# Function to get image priority score for sorting
def get_image_priority(image_path):
    """
    Get priority score for image sorting.
    Lower score = higher priority.
    """
    filename = os.path.basename(image_path).lower()
    
    # Priority 0: Ends with "main" (highest priority)
    if filename.endswith('main'):
        return 0
    
    # Priority 1: Contains "main" but doesn't end with it
    if 'main' in filename and not filename.endswith('main'):
        return 1
    
    # Priority 2: All other images (will be sorted by quality later)
    return 2

# Function to estimate image quality based on file size
def get_image_quality_score(image_path):
    """
    Estimate image quality based on file size.
    Larger files generally mean higher quality.
    """
    try:
        file_size = os.path.getsize(image_path)
        return file_size
    except:
        return 0

# Function to get image files from a folder with relative paths and proper sorting
def get_images_from_folder(folder_path):
    """
    Get all image files from a folder, sorted by priority and quality.
    Returns a list of relative image file paths.
    """
    if not folder_path or not os.path.exists(folder_path):
        return []
    
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp'}
    image_files = []
    
    try:
        for file in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file)
            if os.path.isfile(file_path):
                file_ext = os.path.splitext(file)[1].lower()
                if file_ext in image_extensions:
                    # Create relative path: Images/folder_name/filename
                    folder_name = os.path.basename(folder_path)
                    relative_path = f"Images/{folder_name}/{file}"
                    image_files.append(relative_path)
    except Exception as e:
        print(f"Error reading folder {folder_path}: {e}")
    
    # Sort images by priority and quality
    def sort_key(image_path):
        priority = get_image_priority(image_path)
        # Get the full path for quality scoring
        full_image_path = os.path.join(folder_path, os.path.basename(image_path))
        quality = get_image_quality_score(full_image_path)
        return (priority, -quality)  # Negative quality so larger files come first
    
    return sorted(image_files, key=sort_key)

# Add image folder paths and image files to each deal in the dictionary
for deal in dictionary:
    deal['image_folder_path'] = find_image_folder(deal['pub_name'], image_folders)
    deal['image_files'] = get_images_from_folder(deal['image_folder_path'])

# Get all deals without images
deals_without_images = [deal for deal in dictionary if not deal['image_files']]

# Print count of deals without images
print(f"Total deals without images: {len(deals_without_images)}")

# Print distinct pub names and count of pubs without images
distinct_pub_names_without_images = sorted(set(deal['pub_name'] for deal in deals_without_images))
print(f"Distinct pub names without images ({len(distinct_pub_names_without_images)} total):")
print("=" * 50)

# Print just the distinct pub names
for pub_name in distinct_pub_names_without_images:
    print(pub_name)

# Show example of sorted images for a deal with images
print("\n" + "=" * 50)
print("Example of sorted images for a deal with images:")
for deal in dictionary:
    if deal['image_files']:
        print(f"\nDeal: {deal['pub_name']}")
        print(f"Images ({len(deal['image_files'])} total):")
        for i, img in enumerate(deal['image_files'][:5]):  # Show first 5
            priority = get_image_priority(img)
            print(f"  Position {i}: {os.path.basename(img)} (Priority: {priority})")
        break
# Out:
# Total deals without images: 36
# Distinct pub names without images (18 total):
# ==================================================
# Gassys Cardiff
# Prince Of Teck Earls Court
# Tank & Paddle Manchester Printworks
# Temperance Fulham
# The Bay & Bracket Victoria
# The Block & Gasket Burgess Hill
# The Block & Gasket Sale
# The Boundary Reading
# The Bridge Tap London
# The Cannick Tapps London
# The Centurion Colchester
# The Cider Press Bristol
# The Distillery Leicester
# The Dockyard Portsmouth
# The Faraday Epsom
# The Garratt And Gauge Wimbledon
# The Green Dragon Croydon
# The Joiners London
#
# ==================================================
# Example of sorted images for a deal with images:
